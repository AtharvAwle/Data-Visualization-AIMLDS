# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Categorical Data Plots
'''
boxplot 
violinplot
stripplot
swarmplot
barplot
countplot
'''
# Out:
# '\nboxplot \nviolinplot\nstripplot\nswarmplot\nbarplot\ncountplot\n'

# %%
dataset = sns.load_dataset('tips')
dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# COUNT PLOT - used to categorically count the columns bases on category

sns.countplot(x = dataset['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# If we have to check how many male and female smoke or compare any other category we will use hue and pass another column init
sns.countplot(x = dataset['sex'],hue = dataset['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# Barplot

sns.barplot(x = dataset['sex'], y = dataset['total_bill'])
# in barplot x --> qualitative.  & y --> quantative
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# bar plots also have estimator wherein we can change how quantative axis is measured by mean median sum count

sns.barplot(x = dataset['sex'] , y = dataset['total_bill'] , estimator= np.sum)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# Box Plot
sns.boxplot(x = dataset['tip'], y = dataset['day'], palette='rainbow')
# Out:
# /var/folders/r1/my_pmmwj0s3508q9fdhmmh9m0000gn/T/ipykernel_37133/3174469450.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = dataset['tip'], y = dataset['day'], palette='rainbow')
# <Axes: xlabel='tip', ylabel='day'>

# %%
# violin plot

sns.violinplot(x = 'day',y = 'total_bill',data = dataset)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# strip plot and swam plot
sns.stripplot(x = 'day',y = 'total_bill',data = dataset)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'day',y = 'total_bill',data = dataset)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
